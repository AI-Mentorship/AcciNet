# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, box, Polygon
import numpy as np
import matplotlib.pyplot as plt
import ast
import datetime

# %%
def setupApiFile():
    apiFile = pd.read_csv("../data/processed/crash_street_api_features.csv")

    # remove columns we basically already have
    apiFile.drop(columns={"maxspeed", "road_type"}, inplace=True)

    # just print out before filterin
    print(f"With and without lane count, we have: {apiFile.shape[0]} crashes")

    apiFile = apiFile.dropna(subset=["lane_count"])

    apiFile.fillna(0, inplace=True)

    print(f"With only lane count, we have: {apiFile.shape[0]} crashes")

    for index, crash in apiFile.iterrows():
        try:
            apiFile.at[index, "lane_count"] = int(crash["lane_count"])
        except:
            laneCount = ast.literal_eval(crash["lane_count"])
            laneCount = int(laneCount[0]) + int(laneCount[1])
            apiFile.at[index, "lane_count"] = laneCount
    return apiFile

# %%
apiFile = setupApiFile()
crash_frame = pd.read_csv("../data/processed/encoded_data_binary_encoding.csv")

gdf = gpd.GeoDataFrame(
    crash_frame, 
    geometry=gpd.points_from_xy(crash_frame["Longitude"], crash_frame["Latitude"]), 
    crs="EPSG:4326"
)

# left upper bound - 33°15'08.7"N 97°21'46.3"W
# right lower bound - 32°22'36.5"N 96°07'37.0"W

#using our bounds, create the corners we'll use in our polygon
upperLeft = (-1 * (97 + 21/60 + 46.3/3600), 33 + 15/60 + 8.7/3600)
bottomRight = (-1 * (96 + 7/60 + 37/3600), 32 + 22/60 + 36.5/3600)

upperRight = (bottomRight[0], upperLeft[1])
bottomLeft = (upperLeft[0], bottomRight[1])

# create the polygon
dallasBounds = Polygon([upperLeft, upperRight, bottomRight, bottomLeft, upperLeft])

# create teh dataframe
dallasFrame = gpd.GeoDataFrame({"geometry": [dallasBounds]}, crs="EPSG:4326")

# cahnge coordinate system of both
dallasFrame = dallasFrame.to_crs(epsg=32614)
gdf = gdf.to_crs(epsg=32614)

cell_size = 500

minx, miny, maxx, maxy = dallasFrame.total_bounds

grids = []
index = 0
# create grids based on the bounds
for x in np.arange(minx, maxx, cell_size):
    for y in np.arange(miny, maxy, cell_size):
        grids.append(box(x, y, x+cell_size, y+cell_size))

# 2. Optional: intersect with Dallas boundary to crop
grid = gpd.GeoDataFrame({"geometry": grids}, crs=dallasFrame.crs)

grid = gpd.overlay(grid, dallasFrame, how="intersection")

# combine it based on which cells are matching
joined_data = gpd.sjoin(gdf, grid, how="left", predicate="intersects")

# then, join by api data
joined_data = pd.merge(joined_data, apiFile, on=["Latitude", "Longitude"], how="inner")

final_cells = []

cellId = 0

timeRange = 6

# group by when they go to similar cells
for _, crashes in joined_data.groupby("index_right"):
    cellIndex = crashes.iloc[0]["index_right"]
    print(f'In cell {cellIndex} we have {len(crashes)} crashes!')
    crashes.drop(columns=["index_right", "Crash ID", "geometry"], inplace=True)

    crashes["crash_count_7d"] = 0
    crashes["crash_count_30d"] = 0
    crashes["cell_id"] = cellId
    crashes["label"] = 0

    crashes["Crash Date"] = pd.to_datetime(crashes["Crash Date"], format="%Y-%m-%d")
    crashes = crashes.sort_values(["Crash Date", "Hour of Day"], ascending=True).reset_index(drop=True)

    # loop through each crash to add it to each timeslot
    for i, crash in crashes.iterrows():        
        crashIndex = crash["Hour of Day"]
        # loop through each possible timeslot represneted by j, and put into the cells the value with the correct label based on if the time matches.
        for currentLowerHourBound in range(0, 24, 6):
            currentUpperHourBound = currentLowerHourBound + 5

            crashToAppend = crash.copy()
            # check if the timeslot matches. If so, put crash with label of 1, otherwise keep it as the 0. Also, keep current hour of day
            if(crashIndex >= currentLowerHourBound and crashIndex <= currentUpperHourBound):
                crashToAppend["label"] = 1
            # otherwise, keep label as 0, and make the hour of day the halfway point between the 2 bounds
            else:
                crashToAppend["Hour of Day"] = int((currentLowerHourBound + currentUpperHourBound) / 2)

            rolling_7_count = 0
            rolling_30_count = 0
            currentCrashDate = crash["Crash Date"]
            # loop through previous crashes
            for z in range(i - 1, -1, -1):
                prevCrashDate = crashes.iloc[z]["Crash Date"]
                daysPassed = (currentCrashDate - prevCrashDate).days
                # use this if sattement to add it
                if(daysPassed == 0):
                    prevHour = crashes.iloc[z]["Hour of Day"]
                    if(prevHour < crashToAppend["Hour of Day"]):
                        rolling_7_count += 1
                        rolling_30_count += 1
                if(daysPassed > 30):
                    break
                # note that we don't use an else statement. This way if both are true, it'll be added to both
                if(daysPassed <= 7):
                    rolling_7_count += 1
                if(daysPassed <= 30):
                    rolling_30_count += 1
            # now, add it to the count
            crashToAppend["crash_count_7d"] = rolling_7_count
            crashToAppend["crash_count_30d"] = rolling_30_count
            final_cells.append(crashToAppend)
    cellId += 1
# Out:
# With and without lane count, we have: 41632 crashes
# With only lane count, we have: 33649 crashes
# In cell 12170 we have 27 crashes!
# In cell 12178 we have 5 crashes!
# In cell 12184 we have 13 crashes!
# In cell 12188 we have 61 crashes!
# In cell 12206 we have 82 crashes!
# In cell 12365 we have 46 crashes!
# In cell 12372 we have 1 crashes!
# In cell 12373 we have 4 crashes!
# In cell 12379 we have 9 crashes!
# In cell 12383 we have 167 crashes!
# In cell 12384 we have 29 crashes!
# In cell 12401 we have 62 crashes!
# In cell 12560 we have 129 crashes!
# In cell 12567 we have 35 crashes!
# In cell 12574 we have 22 crashes!
# In cell 12575 we have 5 crashes!
# In cell 12578 we have 64 crashes!
# In cell 12579 we have 10 crashes!
# In cell 12595 we have 15 crashes!
# In cell 12596 we have 103 crashes!
# In cell 12755 we have 104 crashes!
# In cell 12762 we have 39 crashes!
# In cell 12770 we have 18 crashes!
# In cell 12773 we have 27 crashes!
# In cell 12774 we have 1 crashes!
# In cell 12790 we have 1 crashes!
# In cell 12791 we have 48 crashes!
# In cell 12792 we have 44 crashes!
# In cell 12793 we have 24 crashes!
# In cell 12794 we have 15 crashes!
# In cell 12795 we have 80 crashes!
# In cell 12950 we have 58 crashes!
# In cell 12957 we have 46 crashes!
# In cell 12965 we have 9 crashes!
# In cell 12968 we have 22 crashes!
# In cell 12969 we have 29 crashes!
# In cell 12985 we have 21 crashes!
# In cell 12986 we have 119 crashes!
# In cell 12990 we have 1 crashes!
# In cell 12991 we have 20 crashes!
# In cell 13145 we have 105 crashes!
# In cell 13152 we have 34 crashes!
# In cell 13160 we have 16 crashes!
# In cell 13163 we have 13 crashes!
# In cell 13164 we have 8 crashes!
# In cell 13181 we have 74 crashes!
# In cell 13187 we have 78 crashes!
# In cell 13340 we have 44 crashes!
# In cell 13347 we have 25 crashes!
# In cell 13355 we have 16 crashes!
# In cell 13358 we have 31 crashes!
# In cell 13359 we have 1 crashes!
# In cell 13376 we have 49 crashes!
# In cell 13382 we have 3 crashes!
# In cell 13383 we have 19 crashes!
# In cell 13534 we have 3 crashes!
# In cell 13535 we have 35 crashes!
# In cell 13542 we have 64 crashes!
# In cell 13543 we have 22 crashes!
# In cell 13544 we have 8 crashes!
# In cell 13545 we have 55 crashes!
# In cell 13546 we have 25 crashes!
# In cell 13547 we have 10 crashes!
# In cell 13548 we have 17 crashes!
# In cell 13549 we have 38 crashes!
# In cell 13550 we have 122 crashes!
# In cell 13551 we have 38 crashes!
# In cell 13553 we have 125 crashes!
# In cell 13571 we have 141 crashes!
# In cell 13578 we have 3 crashes!
# In cell 13579 we have 4 crashes!
# In cell 13729 we have 9 crashes!
# In cell 13730 we have 7 crashes!
# In cell 13735 we have 21 crashes!
# In cell 13736 we have 35 crashes!
# In cell 13737 we have 20 crashes!
# In cell 13746 we have 7 crashes!
# In cell 13748 we have 34 crashes!
# In cell 13765 we have 34 crashes!
# In cell 13766 we have 55 crashes!
# In cell 13923 we have 1 crashes!
# In cell 13924 we have 122 crashes!
# In cell 13925 we have 18 crashes!
# In cell 13926 we have 7 crashes!
# In cell 13927 we have 4 crashes!
# In cell 13928 we have 1 crashes!
# In cell 13929 we have 6 crashes!
# In cell 13930 we have 1 crashes!
# In cell 13932 we have 12 crashes!
# In cell 13941 we have 11 crashes!
# In cell 13943 we have 22 crashes!
# In cell 13944 we have 4 crashes!
# In cell 13959 we have 31 crashes!
# In cell 13960 we have 4 crashes!
# In cell 13961 we have 41 crashes!
# In cell 14116 we have 21 crashes!
# In cell 14117 we have 1 crashes!
# In cell 14118 we have 1 crashes!
# In cell 14119 we have 21 crashes!
# In cell 14136 we have 14 crashes!
# In cell 14138 we have 1 crashes!
# In cell 14139 we have 20 crashes!
# In cell 14154 we have 77 crashes!
# In cell 14156 we have 136 crashes!
# In cell 14287 we have 2 crashes!
# In cell 14302 we have 1 crashes!
# In cell 14303 we have 4 crashes!
# In cell 14308 we have 4 crashes!
# In cell 14309 we have 12 crashes!
# In cell 14310 we have 9 crashes!
# In cell 14314 we have 16 crashes!
# In cell 14331 we have 5 crashes!
# In cell 14334 we have 29 crashes!
# In cell 14348 we have 2 crashes!
# In cell 14349 we have 9 crashes!
# In cell 14351 we have 43 crashes!
# In cell 14363 we have 5 crashes!
# In cell 14364 we have 50 crashes!
# In cell 14482 we have 9 crashes!
# In cell 14483 we have 5 crashes!
# In cell 14484 we have 3 crashes!
# In cell 14485 we have 1 crashes!
# In cell 14497 we have 5 crashes!
# In cell 14503 we have 8 crashes!
# In cell 14509 we have 154 crashes!
# In cell 14529 we have 7 crashes!
# In cell 14542 we have 1 crashes!
# In cell 14543 we have 37 crashes!
# In cell 14546 we have 43 crashes!
# In cell 14558 we have 13 crashes!
# In cell 14680 we have 3 crashes!
# In cell 14691 we have 2 crashes!
# In cell 14704 we have 31 crashes!
# In cell 14721 we have 3 crashes!
# In cell 14737 we have 4 crashes!
# In cell 14741 we have 33 crashes!
# In cell 14752 we have 14 crashes!
# In cell 14753 we have 23 crashes!
# In cell 14877 we have 2 crashes!
# In cell 14878 we have 9 crashes!
# In cell 14886 we have 4 crashes!
# In cell 14899 we have 2 crashes!
# In cell 14916 we have 15 crashes!
# In cell 14946 we have 3 crashes!
# In cell 14947 we have 63 crashes!
# In cell 15073 we have 9 crashes!
# In cell 15074 we have 10 crashes!
# In cell 15080 we have 6 crashes!
# In cell 15081 we have 38 crashes!
# In cell 15094 we have 15 crashes!
# In cell 15102 we have 8 crashes!
# In cell 15111 we have 8 crashes!
# In cell 15126 we have 15 crashes!
# In cell 15140 we have 2 crashes!
# In cell 15141 we have 51 crashes!
# In cell 15269 we have 1 crashes!
# In cell 15270 we have 14 crashes!
# In cell 15274 we have 37 crashes!
# In cell 15275 we have 6 crashes!
# In cell 15289 we have 102 crashes!
# In cell 15297 we have 1 crashes!
# In cell 15306 we have 24 crashes!
# In cell 15333 we have 74 crashes!
# In cell 15334 we have 12 crashes!
# In cell 15335 we have 65 crashes!
# In cell 15336 we have 10 crashes!
# In cell 15466 we have 33 crashes!
# In cell 15467 we have 1 crashes!
# In cell 15468 we have 12 crashes!
# In cell 15469 we have 13 crashes!
# In cell 15484 we have 79 crashes!
# In cell 15485 we have 12 crashes!
# In cell 15486 we have 9 crashes!
# In cell 15487 we have 10 crashes!
# In cell 15488 we have 5 crashes!
# In cell 15492 we have 3 crashes!
# In cell 15501 we have 4 crashes!
# In cell 15502 we have 1 crashes!
# In cell 15527 we have 32 crashes!
# In cell 15528 we have 1 crashes!
# In cell 15530 we have 20 crashes!
# In cell 15662 we have 99 crashes!
# In cell 15663 we have 23 crashes!
# In cell 15679 we have 12 crashes!
# In cell 15683 we have 2 crashes!
# In cell 15684 we have 13 crashes!
# In cell 15685 we have 6 crashes!
# In cell 15687 we have 1 crashes!
# In cell 15697 we have 10 crashes!
# In cell 15710 we have 32 crashes!
# In cell 15716 we have 29 crashes!
# In cell 15721 we have 5 crashes!
# In cell 15724 we have 26 crashes!
# In cell 15725 we have 4 crashes!
# In cell 15856 we have 57 crashes!
# In cell 15857 we have 10 crashes!
# In cell 15858 we have 9 crashes!
# In cell 15859 we have 7 crashes!
# In cell 15874 we have 6 crashes!
# In cell 15880 we have 3 crashes!
# In cell 15881 we have 10 crashes!
# In cell 15882 we have 43 crashes!
# In cell 15892 we have 2 crashes!
# In cell 15905 we have 15 crashes!
# In cell 15911 we have 140 crashes!
# In cell 16051 we have 22 crashes!
# In cell 16054 we have 41 crashes!
# In cell 16055 we have 10 crashes!
# In cell 16069 we have 31 crashes!
# In cell 16077 we have 1 crashes!
# In cell 16078 we have 17 crashes!
# In cell 16079 we have 1 crashes!
# In cell 16100 we have 32 crashes!
# In cell 16106 we have 61 crashes!
# In cell 16114 we have 6 crashes!
# In cell 16121 we have 3 crashes!
# In cell 16122 we have 94 crashes!
# In cell 16246 we have 42 crashes!
# In cell 16264 we have 31 crashes!
# In cell 16272 we have 1 crashes!
# In cell 16274 we have 17 crashes!
# In cell 16275 we have 5 crashes!
# In cell 16277 we have 12 crashes!
# In cell 16278 we have 25 crashes!
# In cell 16279 we have 38 crashes!
# In cell 16280 we have 26 crashes!
# In cell 16281 we have 42 crashes!
# In cell 16282 we have 75 crashes!
# In cell 16283 we have 1 crashes!
# In cell 16288 we have 1 crashes!
# In cell 16289 we have 10 crashes!
# In cell 16290 we have 13 crashes!
# In cell 16291 we have 6 crashes!
# In cell 16294 we have 41 crashes!
# In cell 16295 we have 112 crashes!
# In cell 16296 we have 29 crashes!
# In cell 16297 we have 24 crashes!
# In cell 16298 we have 57 crashes!
# In cell 16299 we have 27 crashes!
# In cell 16300 we have 41 crashes!
# In cell 16301 we have 57 crashes!
# In cell 16304 we have 21 crashes!
# In cell 16308 we have 2 crashes!
# In cell 16309 we have 4 crashes!
# In cell 16316 we have 4 crashes!
# In cell 16317 we have 39 crashes!
# In cell 16328 we have 6 crashes!
# In cell 16442 we have 14 crashes!
# In cell 16468 we have 1 crashes!
# In cell 16471 we have 45 crashes!
# In cell 16472 we have 22 crashes!
# In cell 16473 we have 2 crashes!
# In cell 16475 we have 4 crashes!
# In cell 16476 we have 2 crashes!
# In cell 16477 we have 4 crashes!
# In cell 16478 we have 14 crashes!
# In cell 16479 we have 16 crashes!
# In cell 16480 we have 18 crashes!
# In cell 16481 we have 197 crashes!
# In cell 16482 we have 28 crashes!
# In cell 16483 we have 21 crashes!
# In cell 16484 we have 53 crashes!
# In cell 16485 we have 15 crashes!
# In cell 16491 we have 11 crashes!
# In cell 16496 we have 69 crashes!
# In cell 16497 we have 240 crashes!
# In cell 16498 we have 67 crashes!
# In cell 16499 we have 110 crashes!
# In cell 16500 we have 7 crashes!
# In cell 16504 we have 5 crashes!
# In cell 16513 we have 21 crashes!
# In cell 16522 we have 43 crashes!
# In cell 16523 we have 237 crashes!
# In cell 16524 we have 44 crashes!
# In cell 16638 we have 4 crashes!
# In cell 16655 we have 5 crashes!
# In cell 16664 we have 2 crashes!
# In cell 16665 we have 7 crashes!
# In cell 16666 we have 6 crashes!
# In cell 16667 we have 1 crashes!
# In cell 16677 we have 20 crashes!
# In cell 16693 we have 68 crashes!
# In cell 16694 we have 12 crashes!
# In cell 16695 we have 20 crashes!
# In cell 16696 we have 47 crashes!
# In cell 16697 we have 7 crashes!
# In cell 16700 we have 23 crashes!
# In cell 16709 we have 35 crashes!
# In cell 16716 we have 13 crashes!
# In cell 16717 we have 114 crashes!
# In cell 16718 we have 71 crashes!
# In cell 16851 we have 156 crashes!
# In cell 16860 we have 38 crashes!
# In cell 16861 we have 56 crashes!
# In cell 16873 we have 25 crashes!
# In cell 16883 we have 1 crashes!
# In cell 16889 we have 91 crashes!
# In cell 16890 we have 21 crashes!
# In cell 16893 we have 4 crashes!
# In cell 16894 we have 47 crashes!
# In cell 16895 we have 199 crashes!
# In cell 16896 we have 1 crashes!
# In cell 16905 we have 89 crashes!
# In cell 16907 we have 33 crashes!
# In cell 16908 we have 320 crashes!
# In cell 16909 we have 70 crashes!
# In cell 16910 we have 59 crashes!
# In cell 16911 we have 74 crashes!
# In cell 16912 we have 131 crashes!
# In cell 17047 we have 5 crashes!
# In cell 17055 we have 5 crashes!
# In cell 17056 we have 2 crashes!
# In cell 17069 we have 59 crashes!
# In cell 17084 we have 25 crashes!
# In cell 17085 we have 13 crashes!
# In cell 17086 we have 1 crashes!
# In cell 17087 we have 6 crashes!
# In cell 17091 we have 87 crashes!
# In cell 17092 we have 39 crashes!
# In cell 17093 we have 129 crashes!
# In cell 17094 we have 63 crashes!
# In cell 17095 we have 337 crashes!
# In cell 17096 we have 25 crashes!
# In cell 17097 we have 19 crashes!
# In cell 17098 we have 403 crashes!
# In cell 17099 we have 89 crashes!
# In cell 17100 we have 9 crashes!
# In cell 17101 we have 301 crashes!
# In cell 17102 we have 70 crashes!
# In cell 17103 we have 10 crashes!
# In cell 17104 we have 1 crashes!
# In cell 17249 we have 1 crashes!
# In cell 17250 we have 28 crashes!
# In cell 17265 we have 41 crashes!
# In cell 17266 we have 130 crashes!
# In cell 17280 we have 20 crashes!
# In cell 17284 we have 4 crashes!
# In cell 17286 we have 53 crashes!
# In cell 17287 we have 301 crashes!
# In cell 17297 we have 67 crashes!
# In cell 17438 we have 34 crashes!
# In cell 17445 we have 24 crashes!
# In cell 17462 we have 14 crashes!
# In cell 17475 we have 51 crashes!
# In cell 17476 we have 3 crashes!
# In cell 17480 we have 3 crashes!
# In cell 17481 we have 73 crashes!
# In cell 17482 we have 31 crashes!
# In cell 17493 we have 69 crashes!
# In cell 17494 we have 1 crashes!
# In cell 17631 we have 90 crashes!
# In cell 17633 we have 60 crashes!
# In cell 17634 we have 9 crashes!
# In cell 17641 we have 9 crashes!
# In cell 17658 we have 3 crashes!
# In cell 17670 we have 12 crashes!
# In cell 17671 we have 24 crashes!
# In cell 17675 we have 2 crashes!
# In cell 17676 we have 13 crashes!
# In cell 17677 we have 2 crashes!
# In cell 17678 we have 87 crashes!
# In cell 17690 we have 163 crashes!
# In cell 17827 we have 17 crashes!
# In cell 17828 we have 30 crashes!
# In cell 17829 we have 70 crashes!
# In cell 17837 we have 28 crashes!
# In cell 17854 we have 102 crashes!
# In cell 17865 we have 11 crashes!
# In cell 17866 we have 30 crashes!
# In cell 17868 we have 16 crashes!
# In cell 17869 we have 103 crashes!
# In cell 17870 we have 10 crashes!
# In cell 17871 we have 47 crashes!
# In cell 17874 we have 60 crashes!
# In cell 17886 we have 182 crashes!
# In cell 18024 we have 30 crashes!
# In cell 18025 we have 97 crashes!
# In cell 18026 we have 4 crashes!
# In cell 18033 we have 17 crashes!
# In cell 18050 we have 138 crashes!
# In cell 18061 we have 265 crashes!
# In cell 18062 we have 28 crashes!
# In cell 18063 we have 112 crashes!
# In cell 18064 we have 10 crashes!
# In cell 18069 we have 53 crashes!
# In cell 18070 we have 4 crashes!
# In cell 18082 we have 63 crashes!
# In cell 18220 we have 72 crashes!
# In cell 18222 we have 68 crashes!
# In cell 18223 we have 30 crashes!
# In cell 18229 we have 1 crashes!
# In cell 18246 we have 19 crashes!
# In cell 18256 we have 144 crashes!
# In cell 18257 we have 85 crashes!
# In cell 18265 we have 34 crashes!
# In cell 18266 we have 5 crashes!
# In cell 18278 we have 2 crashes!
# In cell 18279 we have 37 crashes!
# In cell 18415 we have 80 crashes!
# In cell 18416 we have 17 crashes!
# In cell 18419 we have 17 crashes!
# In cell 18420 we have 50 crashes!
# In cell 18421 we have 9 crashes!
# In cell 18425 we have 8 crashes!
# In cell 18442 we have 24 crashes!
# In cell 18452 we have 212 crashes!
# In cell 18462 we have 44 crashes!
# In cell 18475 we have 174 crashes!
# In cell 18611 we have 53 crashes!
# In cell 18616 we have 16 crashes!
# In cell 18617 we have 41 crashes!
# In cell 18618 we have 38 crashes!
# In cell 18621 we have 43 crashes!
# In cell 18637 we have 27 crashes!
# In cell 18638 we have 113 crashes!
# In cell 18648 we have 28 crashes!
# In cell 18658 we have 1 crashes!
# In cell 18659 we have 44 crashes!
# In cell 18671 we have 40 crashes!
# In cell 18672 we have 19 crashes!
# In cell 18807 we have 111 crashes!
# In cell 18814 we have 11 crashes!
# In cell 18815 we have 26 crashes!
# In cell 18817 we have 15 crashes!
# In cell 18833 we have 29 crashes!
# In cell 18843 we have 124 crashes!
# In cell 18844 we have 135 crashes!
# In cell 18855 we have 9 crashes!
# In cell 18868 we have 53 crashes!
# In cell 19001 we have 1 crashes!
# In cell 19002 we have 5 crashes!
# In cell 19010 we have 12 crashes!
# In cell 19011 we have 36 crashes!
# In cell 19012 we have 122 crashes!
# In cell 19028 we have 17 crashes!
# In cell 19038 we have 48 crashes!
# In cell 19050 we have 2 crashes!
# In cell 19063 we have 12 crashes!
# In cell 19064 we have 61 crashes!
# In cell 19196 we have 45 crashes!
# In cell 19207 we have 19 crashes!
# In cell 19208 we have 50 crashes!
# In cell 19209 we have 20 crashes!
# In cell 19223 we have 49 crashes!
# In cell 19224 we have 20 crashes!
# In cell 19232 we have 59 crashes!
# In cell 19233 we have 98 crashes!
# In cell 19245 we have 17 crashes!
# In cell 19259 we have 222 crashes!
# In cell 19391 we have 221 crashes!
# In cell 19402 we have 11 crashes!
# In cell 19404 we have 48 crashes!
# In cell 19419 we have 135 crashes!
# In cell 19427 we have 63 crashes!
# In cell 19440 we have 6 crashes!
# In cell 19454 we have 63 crashes!
# In cell 19586 we have 27 crashes!
# In cell 19597 we have 13 crashes!
# In cell 19600 we have 53 crashes!
# In cell 19601 we have 46 crashes!
# In cell 19602 we have 45 crashes!
# In cell 19603 we have 7 crashes!
# In cell 19614 we have 29 crashes!
# In cell 19616 we have 4 crashes!
# In cell 19621 we have 8 crashes!
# In cell 19622 we have 190 crashes!
# In cell 19635 we have 8 crashes!
# In cell 19636 we have 5 crashes!
# In cell 19649 we have 69 crashes!
# In cell 19781 we have 31 crashes!
# In cell 19791 we have 40 crashes!
# In cell 19792 we have 3 crashes!
# In cell 19794 we have 29 crashes!
# In cell 19795 we have 71 crashes!
# In cell 19796 we have 6 crashes!
# In cell 19798 we have 108 crashes!
# In cell 19799 we have 95 crashes!
# In cell 19800 we have 13 crashes!
# In cell 19801 we have 19 crashes!
# In cell 19802 we have 62 crashes!
# In cell 19803 we have 41 crashes!
# In cell 19809 we have 191 crashes!
# In cell 19811 we have 15 crashes!
# In cell 19812 we have 8 crashes!
# In cell 19816 we have 76 crashes!
# In cell 19817 we have 11 crashes!
# In cell 19831 we have 34 crashes!
# In cell 19844 we have 225 crashes!
# In cell 19973 we have 7 crashes!
# In cell 19974 we have 66 crashes!
# In cell 19975 we have 50 crashes!
# In cell 19976 we have 201 crashes!
# In cell 19977 we have 38 crashes!
# In cell 19978 we have 24 crashes!
# In cell 19979 we have 34 crashes!
# In cell 19980 we have 31 crashes!
# In cell 19981 we have 68 crashes!
# In cell 19982 we have 18 crashes!
# In cell 19983 we have 70 crashes!
# In cell 19984 we have 31 crashes!
# In cell 19985 we have 16 crashes!
# In cell 19986 we have 67 crashes!
# In cell 19987 we have 66 crashes!
# In cell 19988 we have 25 crashes!
# In cell 19989 we have 9 crashes!
# In cell 19998 we have 43 crashes!
# In cell 19999 we have 2 crashes!
# In cell 20004 we have 63 crashes!
# In cell 20005 we have 16 crashes!
# In cell 20007 we have 8 crashes!
# In cell 20010 we have 10 crashes!
# In cell 20011 we have 362 crashes!
# In cell 20026 we have 14 crashes!
# In cell 20039 we have 91 crashes!
# In cell 20171 we have 28 crashes!
# In cell 20180 we have 33 crashes!
# In cell 20181 we have 5 crashes!
# In cell 20194 we have 150 crashes!
# In cell 20200 we have 145 crashes!
# In cell 20201 we have 283 crashes!
# In cell 20202 we have 359 crashes!
# In cell 20203 we have 329 crashes!
# In cell 20204 we have 73 crashes!
# In cell 20205 we have 288 crashes!
# In cell 20206 we have 2 crashes!
# In cell 20221 we have 77 crashes!
# In cell 20234 we have 144 crashes!
# In cell 20366 we have 43 crashes!
# In cell 20375 we have 7 crashes!
# In cell 20389 we have 13 crashes!
# In cell 20390 we have 86 crashes!
# In cell 20391 we have 69 crashes!
# In cell 20392 we have 217 crashes!
# In cell 20393 we have 51 crashes!
# In cell 20394 we have 127 crashes!
# In cell 20395 we have 153 crashes!
# In cell 20396 we have 37 crashes!
# In cell 20397 we have 30 crashes!
# In cell 20398 we have 96 crashes!
# In cell 20416 we have 65 crashes!
# In cell 20417 we have 4 crashes!
# In cell 20418 we have 3 crashes!
# In cell 20419 we have 19 crashes!
# In cell 20420 we have 2 crashes!
# In cell 20421 we have 2 crashes!
# In cell 20422 we have 24 crashes!
# In cell 20423 we have 5 crashes!
# In cell 20424 we have 8 crashes!
# In cell 20425 we have 12 crashes!
# In cell 20426 we have 16 crashes!
# In cell 20427 we have 8 crashes!
# In cell 20428 we have 12 crashes!
# In cell 20429 we have 229 crashes!
# In cell 20430 we have 29 crashes!
# In cell 20431 we have 55 crashes!
# In cell 20432 we have 49 crashes!
# In cell 20433 we have 19 crashes!
# In cell 20434 we have 42 crashes!
# In cell 20435 we have 75 crashes!
# In cell 20436 we have 8 crashes!
# In cell 20437 we have 46 crashes!
# In cell 20438 we have 11 crashes!
# In cell 20439 we have 10 crashes!
# In cell 20440 we have 15 crashes!
# In cell 20441 we have 5 crashes!
# In cell 20442 we have 35 crashes!
# In cell 20443 we have 8 crashes!
# In cell 20561 we have 123 crashes!
# In cell 20570 we have 18 crashes!
# In cell 20588 we have 7 crashes!
# In cell 20589 we have 342 crashes!
# In cell 20590 we have 178 crashes!
# In cell 20593 we have 177 crashes!
# In cell 20594 we have 293 crashes!
# In cell 20611 we have 86 crashes!
# In cell 20624 we have 93 crashes!
# In cell 20756 we have 32 crashes!
# In cell 20765 we have 10 crashes!
# In cell 20785 we have 249 crashes!
# In cell 20789 we have 68 crashes!
# In cell 20790 we have 85 crashes!
# In cell 20806 we have 6 crashes!
# In cell 20819 we have 61 crashes!
# In cell 20951 we have 9 crashes!
# In cell 20952 we have 1 crashes!
# In cell 20961 we have 24 crashes!
# In cell 20980 we have 58 crashes!
# In cell 20981 we have 174 crashes!
# In cell 20983 we have 145 crashes!
# In cell 20984 we have 144 crashes!
# In cell 20985 we have 204 crashes!
# In cell 20986 we have 179 crashes!
# In cell 20987 we have 153 crashes!
# In cell 20988 we have 144 crashes!
# In cell 20989 we have 78 crashes!
# In cell 20990 we have 84 crashes!
# In cell 21001 we have 37 crashes!
# In cell 21014 we have 316 crashes!
# In cell 21147 we have 4 crashes!
# In cell 21155 we have 6 crashes!
# In cell 21156 we have 36 crashes!
# In cell 21176 we have 150 crashes!
# In cell 21177 we have 106 crashes!
# In cell 21178 we have 35 crashes!
# In cell 21185 we have 25 crashes!
# In cell 21186 we have 134 crashes!
# In cell 21187 we have 59 crashes!
# In cell 21188 we have 2 crashes!
# In cell 21196 we have 21 crashes!
# In cell 21209 we have 238 crashes!
# In cell 21342 we have 38 crashes!
# In cell 21343 we have 2 crashes!
# In cell 21344 we have 20 crashes!
# In cell 21345 we have 1 crashes!
# In cell 21346 we have 35 crashes!
# In cell 21347 we have 7 crashes!
# In cell 21348 we have 23 crashes!
# In cell 21349 we have 5 crashes!
# In cell 21350 we have 9 crashes!
# In cell 21351 we have 4 crashes!
# In cell 21352 we have 5 crashes!
# In cell 21371 we have 223 crashes!
# In cell 21372 we have 356 crashes!
# In cell 21382 we have 2 crashes!
# In cell 21383 we have 71 crashes!
# In cell 21384 we have 145 crashes!
# In cell 21385 we have 31 crashes!
# In cell 21391 we have 4 crashes!
# In cell 21404 we have 126 crashes!
# In cell 21535 we have 2 crashes!
# In cell 21536 we have 14 crashes!
# In cell 21537 we have 146 crashes!
# In cell 21538 we have 88 crashes!
# In cell 21547 we have 36 crashes!
# In cell 21548 we have 1 crashes!
# In cell 21563 we have 127 crashes!
# In cell 21564 we have 44 crashes!
# In cell 21565 we have 27 crashes!
# In cell 21566 we have 13 crashes!
# In cell 21567 we have 58 crashes!
# In cell 21580 we have 63 crashes!
# In cell 21581 we have 64 crashes!
# In cell 21582 we have 45 crashes!
# In cell 21586 we have 26 crashes!
# In cell 21599 we have 142 crashes!
# In cell 21730 we have 4 crashes!
# In cell 21733 we have 20 crashes!
# In cell 21743 we have 36 crashes!
# In cell 21755 we have 60 crashes!
# In cell 21756 we have 106 crashes!
# In cell 21757 we have 56 crashes!
# In cell 21758 we have 9 crashes!
# In cell 21762 we have 258 crashes!
# In cell 21763 we have 69 crashes!
# In cell 21777 we have 10 crashes!
# In cell 21778 we have 109 crashes!
# In cell 21779 we have 66 crashes!
# In cell 21780 we have 100 crashes!
# In cell 21781 we have 126 crashes!
# In cell 21782 we have 119 crashes!
# In cell 21783 we have 42 crashes!
# In cell 21784 we have 171 crashes!
# In cell 21785 we have 39 crashes!
# In cell 21786 we have 46 crashes!
# In cell 21787 we have 52 crashes!
# In cell 21788 we have 136 crashes!
# In cell 21789 we have 74 crashes!
# In cell 21790 we have 60 crashes!
# In cell 21791 we have 129 crashes!
# In cell 21792 we have 57 crashes!
# In cell 21793 we have 89 crashes!
# In cell 21794 we have 239 crashes!
# In cell 21928 we have 31 crashes!
# In cell 21938 we have 28 crashes!
# In cell 21946 we have 4 crashes!
# In cell 21947 we have 5 crashes!
# In cell 21948 we have 14 crashes!
# In cell 21949 we have 18 crashes!
# In cell 21950 we have 10 crashes!
# In cell 21951 we have 1 crashes!
# In cell 21952 we have 1 crashes!
# In cell 21956 we have 14 crashes!
# In cell 21957 we have 18 crashes!
# In cell 21958 we have 50 crashes!
# In cell 21959 we have 121 crashes!
# In cell 21976 we have 34 crashes!
# In cell 21988 we have 1 crashes!
# In cell 21989 we have 314 crashes!
# In cell 21990 we have 60 crashes!
# In cell 22123 we have 13 crashes!
# In cell 22124 we have 87 crashes!
# In cell 22134 we have 22 crashes!
# In cell 22138 we have 3 crashes!
# In cell 22139 we have 18 crashes!
# In cell 22140 we have 53 crashes!
# In cell 22141 we have 4 crashes!
# In cell 22144 we have 51 crashes!
# In cell 22145 we have 3 crashes!
# In cell 22150 we have 32 crashes!
# In cell 22151 we have 22 crashes!
# In cell 22154 we have 51 crashes!
# In cell 22170 we have 20 crashes!
# In cell 22171 we have 1 crashes!
# In cell 22184 we have 27 crashes!
# In cell 22185 we have 29 crashes!
# In cell 22186 we have 44 crashes!
# In cell 22319 we have 29 crashes!
# In cell 22329 we have 7 crashes!
# In cell 22331 we have 15 crashes!
# In cell 22332 we have 25 crashes!
# In cell 22333 we have 39 crashes!
# In cell 22334 we have 7 crashes!
# In cell 22335 we have 21 crashes!
# In cell 22336 we have 5 crashes!
# In cell 22337 we have 2 crashes!
# In cell 22338 we have 2 crashes!
# In cell 22339 we have 38 crashes!
# In cell 22340 we have 28 crashes!
# In cell 22344 we have 7 crashes!
# In cell 22345 we have 12 crashes!
# In cell 22349 we have 106 crashes!
# In cell 22350 we have 11 crashes!
# In cell 22364 we have 17 crashes!
# In cell 22365 we have 8 crashes!
# In cell 22378 we have 79 crashes!
# In cell 22379 we have 16 crashes!
# In cell 22381 we have 103 crashes!
# In cell 22382 we have 68 crashes!
# In cell 22514 we have 172 crashes!
# In cell 22522 we have 1 crashes!
# In cell 22523 we have 16 crashes!
# In cell 22524 we have 26 crashes!
# In cell 22525 we have 35 crashes!
# In cell 22526 we have 3 crashes!
# In cell 22527 we have 16 crashes!
# In cell 22535 we have 58 crashes!
# In cell 22539 we have 43 crashes!
# In cell 22544 we have 29 crashes!
# In cell 22545 we have 118 crashes!
# In cell 22559 we have 50 crashes!
# In cell 22572 we have 17 crashes!
# In cell 22573 we have 73 crashes!
# In cell 22577 we have 143 crashes!
# In cell 22578 we have 88 crashes!
# In cell 22709 we have 86 crashes!
# In cell 22710 we have 24 crashes!
# In cell 22715 we have 30 crashes!
# In cell 22716 we have 23 crashes!
# In cell 22717 we have 5 crashes!
# In cell 22719 we have 2 crashes!
# In cell 22720 we have 32 crashes!
# In cell 22730 we have 19 crashes!
# In cell 22734 we have 10 crashes!
# In cell 22739 we have 10 crashes!
# In cell 22740 we have 65 crashes!
# In cell 22741 we have 21 crashes!
# In cell 22754 we have 6 crashes!
# In cell 22767 we have 119 crashes!
# In cell 22773 we have 35 crashes!
# In cell 22774 we have 68 crashes!
# In cell 22905 we have 15 crashes!
# In cell 22909 we have 12 crashes!
# In cell 22910 we have 28 crashes!
# In cell 22912 we have 1 crashes!
# In cell 22915 we have 3 crashes!
# In cell 22916 we have 3 crashes!
# In cell 22925 we have 2 crashes!
# In cell 22929 we have 11 crashes!
# In cell 22935 we have 114 crashes!
# In cell 22936 we have 5 crashes!
# In cell 22937 we have 9 crashes!
# In cell 22949 we have 26 crashes!
# In cell 22961 we have 106 crashes!
# In cell 22962 we have 19 crashes!
# In cell 22969 we have 42 crashes!
# In cell 22970 we have 204 crashes!
# In cell 22971 we have 39 crashes!
# In cell 23100 we have 13 crashes!
# In cell 23103 we have 7 crashes!
# In cell 23104 we have 1 crashes!
# In cell 23107 we have 2 crashes!
# In cell 23120 we have 7 crashes!
# In cell 23124 we have 5 crashes!
# In cell 23130 we have 30 crashes!
# In cell 23133 we have 7 crashes!
# In cell 23134 we have 7 crashes!
# In cell 23144 we have 28 crashes!
# In cell 23155 we have 52 crashes!
# In cell 23156 we have 115 crashes!
# In cell 23166 we have 51 crashes!
# In cell 23167 we have 135 crashes!
# In cell 23295 we have 91 crashes!
# In cell 23296 we have 9 crashes!
# In cell 23297 we have 8 crashes!
# In cell 23298 we have 1 crashes!
# In cell 23306 we have 3 crashes!
# In cell 23307 we have 2 crashes!
# In cell 23314 we have 57 crashes!
# In cell 23315 we have 5 crashes!
# In cell 23319 we have 5 crashes!
# In cell 23325 we have 92 crashes!
# In cell 23329 we have 26 crashes!
# In cell 23339 we have 1 crashes!
# In cell 23350 we have 32 crashes!
# In cell 23362 we have 4 crashes!
# In cell 23363 we have 61 crashes!
# In cell 23364 we have 39 crashes!
# In cell 23490 we have 4 crashes!
# In cell 23491 we have 145 crashes!
# In cell 23492 we have 1 crashes!
# In cell 23493 we have 2 crashes!
# In cell 23502 we have 3 crashes!
# In cell 23509 we have 31 crashes!
# In cell 23514 we have 3 crashes!
# In cell 23520 we have 210 crashes!
# In cell 23525 we have 11 crashes!
# In cell 23535 we have 31 crashes!
# In cell 23544 we have 205 crashes!
# In cell 23559 we have 42 crashes!
# In cell 23560 we have 105 crashes!
# In cell 23561 we have 50 crashes!
# In cell 23686 we have 1 crashes!
# In cell 23697 we have 13 crashes!
# In cell 23703 we have 10 crashes!
# In cell 23709 we have 22 crashes!
# In cell 23715 we have 36 crashes!
# In cell 23716 we have 3 crashes!
# In cell 23721 we have 4 crashes!
# In cell 23722 we have 17 crashes!
# In cell 23727 we have 7 crashes!
# In cell 23728 we have 1 crashes!
# In cell 23729 we have 4 crashes!
# In cell 23730 we have 39 crashes!
# In cell 23731 we have 2 crashes!
# In cell 23738 we have 78 crashes!
# In cell 23739 we have 79 crashes!
# In cell 23756 we have 28 crashes!
# In cell 23757 we have 101 crashes!
# In cell 23758 we have 11 crashes!
# In cell 23879 we have 28 crashes!
# In cell 23892 we have 8 crashes!
# In cell 23897 we have 75 crashes!
# In cell 23898 we have 1 crashes!
# In cell 23904 we have 6 crashes!
# In cell 23910 we have 52 crashes!
# In cell 23917 we have 6 crashes!
# In cell 23918 we have 5 crashes!
# In cell 23921 we have 14 crashes!
# In cell 23922 we have 12 crashes!
# In cell 23926 we have 17 crashes!
# In cell 23931 we have 8 crashes!
# In cell 23932 we have 109 crashes!
# In cell 23933 we have 39 crashes!
# In cell 24073 we have 23 crashes!
# In cell 24074 we have 48 crashes!
# In cell 24078 we have 14 crashes!
# In cell 24087 we have 6 crashes!
# In cell 24091 we have 10 crashes!
# In cell 24098 we have 4 crashes!
# In cell 24099 we have 2 crashes!
# In cell 24105 we have 18 crashes!
# In cell 24113 we have 6 crashes!
# In cell 24114 we have 27 crashes!
# In cell 24115 we have 9 crashes!
# In cell 24116 we have 16 crashes!
# In cell 24121 we have 14 crashes!
# In cell 24126 we have 89 crashes!
# In cell 24266 we have 7 crashes!
# In cell 24267 we have 25 crashes!
# In cell 24268 we have 44 crashes!
# In cell 24273 we have 13 crashes!
# In cell 24274 we have 16 crashes!
# In cell 24282 we have 12 crashes!
# In cell 24285 we have 28 crashes!
# In cell 24294 we have 34 crashes!
# In cell 24300 we have 224 crashes!
# In cell 24308 we have 13 crashes!
# In cell 24309 we have 55 crashes!
# In cell 24310 we have 3 crashes!
# In cell 24316 we have 18 crashes!
# In cell 24320 we have 73 crashes!
# In cell 24321 we have 96 crashes!
# In cell 24459 we have 12 crashes!
# In cell 24460 we have 26 crashes!
# In cell 24461 we have 9 crashes!
# In cell 24469 we have 25 crashes!
# In cell 24477 we have 31 crashes!
# In cell 24479 we have 5 crashes!
# In cell 24480 we have 25 crashes!
# In cell 24489 we have 9 crashes!
# In cell 24495 we have 35 crashes!
# In cell 24496 we have 24 crashes!
# In cell 24502 we have 21 crashes!
# In cell 24503 we have 11 crashes!
# In cell 24505 we have 8 crashes!
# In cell 24506 we have 3 crashes!
# In cell 24511 we have 9 crashes!
# In cell 24514 we have 1 crashes!
# In cell 24515 we have 50 crashes!
# In cell 24652 we have 28 crashes!
# In cell 24653 we have 13 crashes!
# In cell 24654 we have 2 crashes!
# In cell 24664 we have 22 crashes!
# In cell 24672 we have 12 crashes!
# In cell 24673 we have 1 crashes!
# In cell 24674 we have 24 crashes!
# In cell 24683 we have 3 crashes!
# In cell 24684 we have 15 crashes!
# In cell 24691 we have 80 crashes!
# In cell 24695 we have 11 crashes!
# In cell 24696 we have 13 crashes!
# In cell 24701 we have 17 crashes!
# In cell 24702 we have 13 crashes!
# In cell 24706 we have 5 crashes!
# In cell 24709 we have 5 crashes!
# In cell 24859 we have 10 crashes!
# In cell 24860 we have 9 crashes!
# In cell 24867 we have 23 crashes!
# In cell 24868 we have 10 crashes!
# In cell 24879 we have 9 crashes!
# In cell 24883 we have 37 crashes!
# In cell 24884 we have 23 crashes!
# In cell 24885 we have 107 crashes!
# In cell 24886 we have 63 crashes!
# In cell 24887 we have 23 crashes!
# In cell 24888 we have 41 crashes!
# In cell 24889 we have 17 crashes!
# In cell 24890 we have 1 crashes!
# In cell 24897 we have 13 crashes!
# In cell 24898 we have 19 crashes!
# In cell 24901 we have 19 crashes!
# In cell 24903 we have 57 crashes!
# In cell 25055 we have 13 crashes!
# In cell 25062 we have 89 crashes!
# In cell 25063 we have 23 crashes!
# In cell 25064 we have 13 crashes!
# In cell 25065 we have 11 crashes!
# In cell 25066 we have 8 crashes!
# In cell 25067 we have 66 crashes!
# In cell 25068 we have 33 crashes!
# In cell 25069 we have 56 crashes!
# In cell 25070 we have 42 crashes!
# In cell 25071 we have 38 crashes!
# In cell 25072 we have 24 crashes!
# In cell 25073 we have 20 crashes!
# In cell 25074 we have 50 crashes!
# In cell 25075 we have 28 crashes!
# In cell 25076 we have 20 crashes!
# In cell 25077 we have 21 crashes!
# In cell 25078 we have 10 crashes!
# In cell 25081 we have 84 crashes!
# In cell 25082 we have 9 crashes!
# In cell 25083 we have 1 crashes!
# In cell 25093 we have 10 crashes!
# In cell 25094 we have 5 crashes!
# In cell 25096 we have 11 crashes!
# In cell 25250 we have 139 crashes!
# In cell 25256 we have 1 crashes!
# In cell 25257 we have 3 crashes!
# In cell 25269 we have 22 crashes!
# In cell 25276 we have 1 crashes!
# In cell 25277 we have 8 crashes!
# In cell 25289 we have 1 crashes!
# In cell 25290 we have 1 crashes!
# In cell 25291 we have 19 crashes!
# In cell 25445 we have 28 crashes!
# In cell 25451 we have 9 crashes!
# In cell 25464 we have 10 crashes!
# In cell 25471 we have 43 crashes!
# In cell 25472 we have 11 crashes!
# In cell 25473 we have 41 crashes!
# In cell 25486 we have 1 crashes!
# In cell 25487 we have 18 crashes!
# In cell 25641 we have 8 crashes!
# In cell 25646 we have 3 crashes!
# In cell 25647 we have 51 crashes!
# In cell 25660 we have 10 crashes!
# In cell 25667 we have 7 crashes!
# In cell 25682 we have 102 crashes!
# In cell 25838 we have 17 crashes!
# In cell 25842 we have 13 crashes!
# In cell 25856 we have 14 crashes!
# In cell 25862 we have 1 crashes!
# In cell 26034 we have 81 crashes!
# In cell 26038 we have 41 crashes!
# In cell 26051 we have 1 crashes!
# In cell 26052 we have 2 crashes!
# In cell 26058 we have 31 crashes!
# In cell 26072 we have 49 crashes!
# In cell 26073 we have 10 crashes!
# In cell 26230 we have 7 crashes!
# In cell 26234 we have 32 crashes!
# In cell 26247 we have 1 crashes!
# In cell 26248 we have 12 crashes!
# In cell 26254 we have 4 crashes!
# In cell 26259 we have 16 crashes!
# In cell 26268 we have 193 crashes!
# In cell 26426 we have 4 crashes!
# In cell 26427 we have 4 crashes!
# In cell 26429 we have 11 crashes!
# In cell 26430 we have 5 crashes!
# In cell 26444 we have 27 crashes!
# In cell 26450 we have 6 crashes!
# In cell 26455 we have 16 crashes!
# In cell 26456 we have 28 crashes!
# In cell 26462 we have 1 crashes!
# In cell 26463 we have 37 crashes!
# In cell 26464 we have 1 crashes!
# In cell 26623 we have 92 crashes!
# In cell 26624 we have 7 crashes!
# In cell 26625 we have 31 crashes!
# In cell 26640 we have 11 crashes!
# In cell 26646 we have 9 crashes!
# In cell 26652 we have 62 crashes!
# In cell 26657 we have 38 crashes!
# In cell 26658 we have 108 crashes!
# In cell 26819 we have 34 crashes!
# In cell 26820 we have 125 crashes!
# In cell 26836 we have 4 crashes!
# In cell 26837 we have 2 crashes!
# In cell 26842 we have 33 crashes!
# In cell 26848 we have 33 crashes!
# In cell 26849 we have 318 crashes!
# In cell 26850 we have 31 crashes!
# In cell 26851 we have 102 crashes!
# In cell 26852 we have 134 crashes!
# In cell 26853 we have 8 crashes!
# In cell 27015 we have 8 crashes!
# In cell 27016 we have 86 crashes!
# In cell 27017 we have 47 crashes!
# In cell 27033 we have 59 crashes!
# In cell 27035 we have 13 crashes!
# In cell 27036 we have 55 crashes!
# In cell 27038 we have 143 crashes!
# In cell 27039 we have 26 crashes!
# In cell 27040 we have 2 crashes!
# In cell 27041 we have 46 crashes!
# In cell 27042 we have 193 crashes!
# In cell 27043 we have 48 crashes!
# In cell 27044 we have 1 crashes!
# In cell 27045 we have 21 crashes!
# In cell 27046 we have 27 crashes!
# In cell 27064 we have 9 crashes!
# In cell 27211 we have 16 crashes!
# In cell 27227 we have 4 crashes!
# In cell 27228 we have 14 crashes!
# In cell 27229 we have 178 crashes!
# In cell 27230 we have 21 crashes!
# In cell 27231 we have 14 crashes!
# In cell 27232 we have 26 crashes!
# In cell 27234 we have 11 crashes!
# In cell 27242 we have 18 crashes!
# In cell 27243 we have 3 crashes!
# In cell 27260 we have 6 crashes!
# In cell 27406 we have 25 crashes!
# In cell 27407 we have 3 crashes!
# In cell 27421 we have 6 crashes!
# In cell 27422 we have 6 crashes!
# In cell 27423 we have 8 crashes!
# In cell 27425 we have 16 crashes!
# In cell 27439 we have 58 crashes!
# In cell 27457 we have 17 crashes!
# In cell 27601 we have 1 crashes!
# In cell 27602 we have 6 crashes!
# In cell 27621 we have 11 crashes!
# In cell 27626 we have 80 crashes!
# In cell 27635 we have 7 crashes!
# In cell 27636 we have 20 crashes!
# In cell 27653 we have 1 crashes!
# In cell 27797 we have 20 crashes!
# In cell 27817 we have 19 crashes!
# In cell 27822 we have 9 crashes!
# In cell 27832 we have 16 crashes!
# In cell 27992 we have 2 crashes!
# In cell 27993 we have 36 crashes!
# In cell 28013 we have 16 crashes!
# In cell 28018 we have 12 crashes!
# In cell 28028 we have 2 crashes!
# In cell 28029 we have 52 crashes!
# In cell 28044 we have 11 crashes!
# In cell 28045 we have 13 crashes!
# In cell 28188 we have 26 crashes!
# In cell 28209 we have 26 crashes!
# In cell 28214 we have 58 crashes!
# In cell 28225 we have 75 crashes!
# In cell 28226 we have 2 crashes!
# In cell 28240 we have 4 crashes!
# In cell 28403 we have 2 crashes!
# In cell 28404 we have 4 crashes!
# In cell 28409 we have 8 crashes!
# In cell 28420 we have 1 crashes!
# In cell 28421 we have 25 crashes!
# In cell 28435 we have 20 crashes!
# In cell 28598 we have 13 crashes!
# In cell 28599 we have 1 crashes!
# In cell 28604 we have 3 crashes!
# In cell 28616 we have 41 crashes!
# In cell 28630 we have 40 crashes!
# In cell 28793 we have 1 crashes!
# In cell 28794 we have 2 crashes!
# In cell 28798 we have 16 crashes!
# In cell 28799 we have 1 crashes!
# In cell 28811 we have 2 crashes!
# In cell 28812 we have 10 crashes!
# In cell 28825 we have 27 crashes!
# In cell 28975 we have 6 crashes!
# In cell 28990 we have 6 crashes!
# In cell 28993 we have 25 crashes!
# In cell 29007 we have 72 crashes!
# In cell 29008 we have 1 crashes!
# In cell 29020 we have 55 crashes!
# In cell 29170 we have 1 crashes!
# In cell 29186 we have 8 crashes!
# In cell 29187 we have 15 crashes!
# In cell 29188 we have 29 crashes!
# In cell 29202 we have 4 crashes!
# In cell 29203 we have 20 crashes!
# In cell 29215 we have 29 crashes!
# In cell 29382 we have 23 crashes!
# In cell 29383 we have 132 crashes!
# In cell 29398 we have 27 crashes!
# In cell 29410 we have 23 crashes!
# In cell 29578 we have 31 crashes!
# In cell 29593 we have 1 crashes!
# In cell 29594 we have 37 crashes!
# In cell 29605 we have 44 crashes!
# In cell 29773 we have 21 crashes!
# In cell 29789 we have 38 crashes!
# In cell 29790 we have 10 crashes!
# In cell 29800 we have 9 crashes!
# In cell 29967 we have 20 crashes!
# In cell 29985 we have 15 crashes!
# In cell 29986 we have 28 crashes!
# In cell 29995 we have 6 crashes!
# In cell 30162 we have 60 crashes!
# In cell 30181 we have 46 crashes!
# In cell 30190 we have 5 crashes!
# In cell 30357 we have 40 crashes!
# In cell 30377 we have 40 crashes!
# In cell 30385 we have 1 crashes!
# In cell 30386 we have 44 crashes!
# In cell 30552 we have 33 crashes!
# In cell 30572 we have 25 crashes!
# In cell 30573 we have 10 crashes!
# In cell 30581 we have 9 crashes!
# In cell 30582 we have 12 crashes!
# In cell 30747 we have 20 crashes!
# In cell 30768 we have 73 crashes!
# In cell 30777 we have 155 crashes!
# In cell 30941 we have 18 crashes!
# In cell 30942 we have 22 crashes!
# In cell 30963 we have 32 crashes!
# In cell 30972 we have 38 crashes!

# %%
exportedDf = pd.DataFrame(final_cells)

exportedDf.drop(columns="Crash Date", inplace=True)

exportedDf.to_csv("../data/final/true_preprocessed_data.csv", index=False)
