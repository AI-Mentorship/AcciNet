# %%
import geopandas as gpd

gdb_path = r"../../data/txdotCSVs/TxDOT_DCIS_All_Projects.gdb"

# Load the only layer
projects = gpd.read_file(gdb_path, layer="TxDOT_DCIS_All_Projects")

# See columns
print(projects.columns)

# See first few rows
print(projects.head())
# Out:
# c:\Users\mahd\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyogrio\raw.py:198: UserWarning: Measured (M) geometry types are not supported. Original type 'Measured MultiLineString' is converted to 'MultiLineString'
#   return ogr_read(
# Index(['CONTROL_SECT_JOB', 'DISTRICT_NUMBER', 'COUNTY_NUMBER',
#        'HIGHWAY_NUMBER', 'PROJ_CLASS', 'TYPE_OF_WORK', 'LIMITS_FROM',
#        'LIMITS_TO', 'LAYMAN_DESCRIPTION1', 'LAYMAN_DESCRIPTION2',
#        'BEG_MILE_POINT', 'END_MILE_POINT', 'PRIORITY_CODE', 'DIST_LET_DATE',
#        'LET_SCH_1', 'LET_SCH_2', 'LET_SCH_3', 'TRUNK_SYS_FLAG', 'FREIGHT',
#        'ENERGY', 'EST_CONST_COST', 'CONTROL_SECTION', 'LOC_ERROR',
#        'Shape_Length', 'geometry'],
#       dtype='object')
#   CONTROL_SECT_JOB  DISTRICT_NUMBER  COUNTY_NUMBER HIGHWAY_NUMBER PROJ_CLASS  \
# 0        001503029              9.0           74.0          IH 35         BR
# 1        000302041             24.0           55.0          IH 10        RER
# ...
