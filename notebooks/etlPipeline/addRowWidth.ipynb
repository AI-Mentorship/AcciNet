# %%
from doSpatialJoin import joinCSVs

joinedDf = joinCSVs("../../data/processed/dataset_v2.csv", "../../data/txdotCSVs/TxDOT_Roadbed_Width.shp", ["geometry", "RDBD_WIDTH"])

joinedDf.to_csv("../../data/processed/dataset_v3.csv")
# Out:
#    Unnamed: 0         cell_id  Longitude   Latitude  Crash Date Crash Time  \
# 0           0   7357278979592 -97.571680  32.828264  2025-10-24   06:30:00
# 1           1   6227702580279 -98.976038  30.738692  2025-09-22   06:39:00
# 2           2  10136122820215 -94.091867  33.240935  2025-10-04   17:00:00
# 3           3   7554847474476 -97.382640  29.525534  2025-07-03   03:59:00
# 4           4   8199092569375 -96.554425  31.763599  2025-08-01   06:00:00
#
#    Hour of Day  Day of Week  crash_count_7d  crash_count_20d  ...  \
# 0            6            5               0                0  ...
# 1            6            1               0                0  ...
# 2           17            6               0                0  ...
# 3            3            4               0                0  ...
# 4            6            5               0                0  ...
#
#    nn_cos_x_f8  nn_sin_y_f8  nn_cos_y_f8  nn_sin_x_f16  nn_cos_x_f16  \
# ...
